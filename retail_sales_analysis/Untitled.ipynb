# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
path=r"C:\Users\shish\OneDrive\Desktop\python class\SQL\project\retail_sales_analysis\SQL - Retail Sales Analysis_utf .csv"
df=pd.read_csv(path)

# %%
DATABASE_URL = "mysql+pymysql://root:shishir123@localhost/retail_sale"
engine=create_engine(DATABASE_URL)
df.to_sql(
    name='sale',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 2000
