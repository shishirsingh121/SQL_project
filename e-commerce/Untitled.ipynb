# %%
from sqlalchemy import create_engine
import pandas as pd

# 1️⃣ create database connection
engine = create_engine("mysql+pymysql://root:shishir123@localhost/ecommerce")
# examples:
# sqlite:///mydb.sqlite
# postgresql://user:password@localhost:5432/mydb

# 2️⃣ read csv
df = pd.read_csv(r"C:\Users\shish\OneDrive\Desktop\python class\SQL\project\e-commerce\ecommerce_10000.csv")

# 3️⃣ write to SQL table
df.to_sql(
    name="orders",
    con=engine,
    if_exists="replace",   # or "append"
    index=False
)

print("CSV loaded successfully!")
# Out:
# CSV loaded successfully!
